# %%
print()

# %% [markdown]
# # Dict
#
# dict is a datatype in python, syntax `key:value` dictionary
#
# ![image.png](attachment:image.png)

# %%
thisdict={
    "name":"brahma reddy",
    "id":"434",
    "status":"active",
}

# %%
print(thisdict)
# Out:
# {'name': 'brahma reddy', 'id': '434', 'status': 'active'}

# %%
#Dictionary Items

# %% [markdown]
# Dictionary Items

# %%
print(thisdict["name"])
# Out:
# brahma reddy

# %% [markdown]
# Duplicates Not Allowed

# %%
thisdict={
    "name":"brahma reddy",
    "id":"434",
    "status":"active",
    "status":"inactive"
}

# %%
print(thisdict)
# Out:
# {'name': 'brahma reddy', 'id': '434', 'status': 'inactive'}

# %% [markdown]
# Accessing Items

# %%
thisdict={
    "name":"brahma reddy",
    "id":"434",
    "status":"active",
    "status":"inactive"
}
x=thisdict["status"]
print(x)
# Out:
# inactive

# %% [markdown]
# **Get Keys**

# %%
thisdict={
    "name":"brahma reddy",
    "id":"434",
    "status":"active",
    "status":"inactive"
}
x=thisdict.keys()
print(x)
# Out:
# dict_keys(['name', 'id', 'status'])

# %% [markdown]
# #add new item to dictionary

# %%
thisdict={
    "name":"brahma reddy",
    "id":"434",
    "status":"inactive"
}
x=thisdict.keys()
print(x)
thisdict["phno"]="8186927434"
print(thisdict)
# Out:
# dict_keys(['name', 'id', 'status'])
# {'name': 'brahma reddy', 'id': '434', 'status': 'inactive', 'phno': '8186927434'}

# %% [markdown]
# **Get Values**

# %%
x=thisdict.values()
print(x)
# Out:
# dict_values(['brahma reddy', '434', 'inactive', '8186927434'])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.values()

print(x) 

car["color"] = "red"

print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
x=softsuave.items()
print(x)
# Out:
# dict_items([('name', 'softsuave'), ('version', '1.0.0'), ('description', 'softsuave'), ('author', 'softsuave'), ('license', 'MIT')])

# %% [markdown]
# check key is in dict or not

# %%
if "version434" in softsuave:
    print("soft suave company in chennai")
else: 
    print ("softsuave is not a software company")
# Out:
# softsuave is not a software company

# %% [markdown]
# **Change Values**

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
print(softsuave["license"])
softsuave["license"]="Chennai"
print(softsuave["license"])
# Out:
# MIT
# Chennai

# %% [markdown]
# **Update Dictionary**

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
softsuave.update({"emp":"brahma reddy"})
print(softsuave)
# Out:
# {'name': 'softsuave', 'version': '1.0.0', 'description': 'softsuave', 'author': 'softsuave', 'license': 'MIT', 'emp': 'brahma reddy'}

# %% [markdown]
# **remove the items**

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
softsuave.pop("version")
print(softsuave)
# Out:
# {'name': 'softsuave', 'description': 'softsuave', 'author': 'softsuave', 'license': 'MIT'}

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
softsuave.popitem()
print(softsuave)
# Out:
# {'name': 'softsuave', 'version': '1.0.0', 'description': 'softsuave', 'author': 'softsuave'}

# %% [markdown]
# for removing items from the dict we are using the pop() and popitem() methods.pop() remove the items from the dict based on the key we passed as an argument.and popitem() removes the item which is last inserted in the dict

# %% [markdown]
# del keyword also used for the delete the items from the dict and also used for delete the dict

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
del softsuave["author"]
print(softsuave)
# Out:
# {'name': 'softsuave', 'version': '1.0.0', 'description': 'softsuave', 'license': 'MIT'}

# %% [markdown]
# syntax for delete the dict::
# del dictionaryname
# ex;del softsuave

# %% [markdown]
# **Loop Through a Dictionary**

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
for x in softsuave:
    print(x)
# Out:
# name
# version
# description
# author
# license

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
for x in softsuave:
    print(softsuave[x])
# Out:
# softsuave
# 1.0.0
# softsuave
# softsuave
# MIT

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
for x in softsuave.keys():
    print(x)
# Out:
# name
# version
# description
# author
# license

# %%
for x in softsuave.values():
    print(x)
# Out:
# softsuave
# 1.0.0
# softsuave
# softsuave
# MIT

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
for x,y in softsuave.items():
    print(x,y)
# Out:
# name softsuave
# version 1.0.0
# description softsuave
# author softsuave
# license MIT

# %% [markdown]
# **Copy a Dictionary**

# %% [markdown]
# You cannot copy a dictionary simply by typing dict2 = dict1, because: dict2 will only be a reference to dict1, and changes made in dict1 will automatically also be made in dict2.

# %% [markdown]
# for copy the dict in the python we are using the dict constructor and copy menthod
# `syntax=
# dict1=dict2.copy()
# or
# dict1=dict(dict2)`

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
brahma=softsuave.copy()
print(brahma)
# Out:
# {'name': 'softsuave', 'version': '1.0.0', 'description': 'softsuave', 'author': 'softsuave', 'license': 'MIT'}

# %%
softsuave={
    "name":"softsuave",
    "version":"1.0.0",
    "description":"softsuave",
    "author":"softsuave",
    "license":"MIT",
}
brahma=dict(softsuave)
print(brahma)
# Out:
# {'name': 'softsuave', 'version': '1.0.0', 'description': 'softsuave', 'author': 'softsuave', 'license': 'MIT'}

# %% [markdown]
# **Nested Dictionaries`
# A dictionary can contain dictionaries, this is called nested dictionaries.`**

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %% [markdown]
# Accessing the values in the nested dictionaries

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily["child1"]["name"])
# Out:
# Emil

# %% [markdown]
# **to get the length of dict**
# `syntax=len(dictionary name)`

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(len(myfamily))
# Out:
# 3

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(len(myfamily["child1"]))
# Out:
# 2

# %% [markdown]
# ** to get the type of the dictionary **
# `syntax=type(dictionary name)`

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(type(myfamily))
# Out:
# <class 'dict'>

# %% [markdown]
# ** all methods of dictionary **
# clear()	Removes all the elements from the dictionary

# %% [markdown]
# copy()	Returns a copy of the dictionary

# %% [markdown]
# fromkeys()	Returns a dictionary with the specified keys and value

# %% [markdown]
# get()	Returns the value of the specified key

# %% [markdown]
# items()	Returns a list containing a tuple for each key value pair

# %% [markdown]
# keys()	Returns a list containing the dictionary's keys

# %% [markdown]
# pop()	Removes the element with the specified key

# %% [markdown]
# popitem()	Removes the last inserted key-value pair

# %% [markdown]
# setdefault()	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value

# %% [markdown]
# update()	Updates the dictionary with the specified key-value pairs

# %% [markdown]
# values()	Returns a list of all the values in the dictionary

# %% [markdown]
# **TUPLE IN PYTHON**

# %% [markdown]
# Tuples are used to store multiple items in a single variable.

# %% [markdown]
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.

# %% [markdown]
# A tuple is a collection which is ordered and unchangeable.

# %% [markdown]
# Tuples are written with round brackets.

# %%
Tuple=("chennai","hyderabad","guntur")
print(Tuple)
# Out:
# ('chennai', 'hyderabad', 'guntur')

# %% [markdown]
#  GET Tuple Items

# %% [markdown]
# Tuple items are ordered, unchangeable, and allow duplicate values.

# %% [markdown]
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.

# %% [markdown]
# tuple is fixed one after the tuple is created we can not change the tuple i.e we can't add or remove or change the items in the tuple

# %% [markdown]
# To get the tuple length

# %%
ram=("king","Brahma")
print(len(ram))
# Out:
# 2

# %% [markdown]
# how to know the datatype of tuple

# %%
ram=("king")
print(type(ram))
# Out:
# <class 'str'>

# %% [markdown]
# A tuple can contain different data types:

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(tuple1)
# Out:
# ('abc', 34, True, 40, 'male')

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(type(tuple1))
# Out:
# <class 'tuple'>

# %% [markdown]
# Tuple Constructor

# %%
tup=tuple(("ram","bheem","kiran"))
print(tup)
# Out:
# ('ram', 'bheem', 'kiran')

# %% [markdown]
# Access tuple items

# %%
tup=tuple(("ram","bheem","kiran"))
print(tup[0])
# Out:
# ram

# %%
tup=tuple(("ram","bheem","kiran"))
print(tup[-1])
# Out:
# kiran

# %% [markdown]
# In the above example we are giving the negative index that means it can select from last onwords

# %% [markdown]
# and also we can print range of items from tuple in python
# `syntax=tuple[0:2]` it will print the 0 and 1 index items i.e [2-0]two items

# %%
tup=tuple(("ram","bheem","kiran"))
print(tup[0:2])
# Out:
# ('ram', 'bheem')

# %%
tup=tuple(("ram","bheem","kiran"))
print(tup[-3:-1])
# Out:
# ('ram', 'bheem')

# %% [markdown]
# Check if Item Exists

# %%
tup=tuple(("ram","bheem","kiran"))
if "ram" in tup:
    print("yes")
# Out:
# yes

# %% [markdown]
# update the tuple

# %% [markdown]
# as we know once tuple is created we cannot modify that,for that we use one alternative

# %% [markdown]
# first we convert the tuple to list

# %% [markdown]
# we change the list items

# %% [markdown]
# then we add list to tuple

# %%
tup=tuple(("ram","bheem","kiran"))
tup[0]="king"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 tup=tuple(("ram","bheem","kiran"))
# ----> 2 tup[0]="king"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup=tuple(("ram","bheem","kiran"))
x=list(tup)
x[0]="king"
tup=tuple(x)
print(tup)
# Out:
# ('king', 'bheem', 'kiran')

# %% [markdown]
# add tuple to tuple`Note: When creating a tuple with only one item, remember to include a comma after the item, otherwise it will not be identified as a tuple.`

# %%
tup=tuple(("ram","bheem","kiran"))
tup2=tuple(("king",))
tup+=tup2
print(tup)
# Out:
# ('ram', 'bheem', 'kiran', 'king')

# %% [markdown]
# ** if you want to remove or add or update the items in the tuple first we convert tuple into list and perform any operation and then convert thar list to tuple **

# %% [markdown]
# in list append() is used for add the items and remove() method is used to remove the items and

# %% [markdown]
# ** for delete the tuple **

# %%
ram=("king",)
del ram
print(ram)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 ram=("king",)
#       2 del ram
# ----> 3 print(ram)
#
# NameError: name 'ram' is not defined

# %%
ram=("king","softsuave")
(person,company)=ram
print(person)
print(company)
# Out:
# king
# softsuave

# %% [markdown]
# in the above example we can unpack the tuple and added to the variables

# %% [markdown]
# using asteric* unpack:::: if the number of variables is less than the number of values in the tuple the we use the asteric* to the last variable thar variable can store the all the remaining vlaues of the tuple as list

# %%
ram=("king","rami","soft","suave")
(me,*all)=ram
print(all)
# Out:
# ['rami', 'soft', 'suave']

# %%
for x in all:
    print(x)
# Out:
# rami
# soft
# suave

# %% [markdown]
# loop on tuple

# %%
ram=("ram","bheem")
for x in ram:
  print(x)
# Out:
# ram
# bheem

# %% [markdown]
# loop through idex values

# %%
ram=("ram","bheem")
for  i in range(len(ram)):
    print(ram[i])
# Out:
# ram
# bheem

# %% [markdown]
# using while loop

# %%
ram=("ram","bheem")
i=0
while i<len(ram):
    print(ram[i])
    i=i+1
# Out:
# ram
# bheem

# %%
ram=("ram","bheem")
ram1=("rami","aaa")
jointuple=ram+ram1
print(jointuple)
# Out:
# ('ram', 'bheem', 'rami', 'aaa')

# %%
ram=("ram","bheem")
ram1=("rami","aaa")
multipletuple=ram*2
print(multipletuple)
# Out:
# ('ram', 'bheem', 'ram', 'bheem')

# %% [markdown]
# ** tuple methods**

# %% [markdown]
# Python Tuple count() Method

# %%
ram=(1,2,3,4,5,1,2,3,5)
print(ram.count(5))
# Out:
# 2

# %% [markdown]
# count() method requires one parameter this method returns the number of times that item repeated in the tuple

# %% [markdown]
# **Python Tuple index() Method**

# %% [markdown]
# index() method return the first occurance of the item idex

# %%
ram=(1,2,3,1)
print(ram.index(1))
# Out:
# 0
